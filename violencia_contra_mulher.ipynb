# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import pathlib
from pathlib import Path
import os
import duckdb

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Violência contra mulheres

# %%
BASE_PATH = Path("/home/matsa/Documents/Faculdade/SAD/tp01/dados_violencia_contra_mulher_SES/")

# %%
def concat_datasets(datasets_path:pathlib.Path, output_filename):
    with duckdb.connect("db.db") as con:
        output_file = Path(datasets_path / f"{output_filename}.csv")
        
        query = f"""
        COPY (
            SELECT * 
            FROM read_csv_auto('{datasets_path}/*.csv', union_by_name=True)
        )
        TO '{output_file}' WITH (FORMAT CSV, HEADER TRUE);
        """

        con.execute(query)
        print(f"Files of {datasets_path} concatenated and saved to {output_file}")

concat_datasets(BASE_PATH, "dados_violencia_mulheres_ses_concat")
# Out:
# Files of /home/matsa/Documents/Faculdade/SAD/tp01/dados_violencia_contra_mulher_SES concatenated and saved to /home/matsa/Documents/Faculdade/SAD/tp01/dados_violencia_contra_mulher_SES/dados_violencia_mulheres_ses_concat.csv

# %%
df_concat = pd.read_csv("./dados_violencia_contra_mulher_SES/dados_violencia_mulheres_ses_concat.csv", sep=",")

display(df_concat.head())
print(f"Shape: {df_concat.shape}")
# Out:
#    dt_notific     dt_nasc nu_idade_n   cs_sexo   cs_raca  \
# 0  2010-08-03  1937-11-02         72  Feminino     Parda
# 1  2010-02-07  1992-04-30         17  Feminino     Parda
# 2  2010-06-28  2003-04-07          7  Feminino  Ignorado
# 3  2010-01-07  1963-05-07         46  Feminino     Parda
# 4  2010-05-20  1917-08-01         92  Feminino    Branca
#
#              id_mn_resi  local_ocor out_vezes les_autop viol_fisic viol_psico  \
# 0  Governador Valadares  Residencia       Sim       Não        Sim        Sim
# 1         Montes Claros  Residencia  Ignorado       Não        Sim        Sim
# 2  Governador Valadares    Ignorado  Ignorado       Não        Não        Sim
# 3   São José do Goiabal  Residencia  Ignorado       NaN        Não        Não
# 4         Jaboticatubas  Residencia       Sim       NaN        Não        Não
#
#   viol_sexu    num_envolv autor_sexo orient_sex ident_gen
# 0       Não            Um  Masculino        NaN       NaN
# 1       NaN            Um  Masculino        NaN       NaN
# 2       Sim            Um  Masculino        NaN       NaN
# 3       Não            Um   Feminino        NaN       NaN
# 4       Não  Dois ou mais  Masculino        NaN       NaN
# Shape: (472046, 16)

# %%
df_concat["cs_sexo"].value_counts()
# Out:
# cs_sexo
# Feminino    472046
# Name: count, dtype: int64

# %%
df_concat.dtypes
# Out:
# dt_notific    object
# dt_nasc       object
# nu_idade_n    object
# cs_sexo       object
# cs_raca       object
# id_mn_resi    object
# local_ocor    object
# out_vezes     object
# les_autop     object
# viol_fisic    object
# viol_psico    object
# viol_sexu     object
# num_envolv    object
# autor_sexo    object
# orient_sex    object
# ident_gen     object
# dtype: object

# %%
df_concat.isna().sum()
# Out:
# dt_notific        0
# dt_nasc        6068
# nu_idade_n       36
# cs_sexo           0
# cs_raca        5982
# id_mn_resi     1265
# local_ocor    11717
# out_vezes     15529
# les_autop     15789
# viol_fisic    12715
# viol_psico    17370
# viol_sexu     17863
# num_envolv    18096
# autor_sexo    13492
# orient_sex    79176
# ident_gen     79176
# dtype: int64

# %%
duplicated_rows = df_concat[df_concat.duplicated(keep=False)]

duplicated_count = duplicated_rows.groupby(
    list(df_concat.columns)
).size().reset_index(name="duplicates_count")

display(duplicated_count.head(16))
print("Duplicates count: ", duplicated_count.shape[0], "\n")
print(duplicated_count["duplicates_count"].value_counts())
# Out:
#     dt_notific     dt_nasc nu_idade_n   cs_sexo   cs_raca  \
# 0   2014-07-11  1991-03-04       23,0  Feminino     Parda
# 1   2014-10-14  1962-10-10       51,0  Feminino  Ignorado
# 2   2014-10-19  1980-04-14       34,0  Feminino     Parda
# 3   2014-10-25  1993-03-12       21,0  Feminino     Parda
# 4   2014-10-28  2013-05-10        1,0  Feminino     Parda
# 5   2014-11-08  1994-08-03       20,0  Feminino    Branca
# 6   2014-11-19  1976-03-16       38,0  Feminino    Branca
# 7   2014-11-21  1996-02-18       18,0  Feminino     Preta
# 8   2014-12-18  1962-07-08       52,0  Feminino    Branca
# 9   2014-12-31  1984-11-27       30,0  Feminino    Branca
# 10  2015-01-07  2002-09-10       12,0  Feminino     Parda
# 11  2015-01-09  1974-11-17       40,0  Feminino    Branca
# 12  2015-01-18  1995-11-28       19,0  Feminino     Parda
# 13  2015-02-02  1964-02-08       50,0  Feminino    Branca
# 14  2015-02-05  1989-04-15       25,0  Feminino     Parda
# 15  2015-02-24  1991-05-07       23,0  Feminino    Branca
#
#                id_mn_resi         local_ocor out_vezes les_autop viol_fisic  \
# 0                   Prata         Residencia       Sim       Não        Sim
# 1               Congonhas           Ignorado  Ignorado  Ignorado        Sim
# 2                 Uberaba         Residencia       Sim       Não        Sim
# 3                 Itabira        Via pública       Não       Não        Não
# 4                  Pompéu         Residencia       Não       Não        Sim
# 5                Urucânia         Residencia       Sim       Sim        Não
# 6            Nova Serrana         Residencia       Não       Não        Sim
# 7        Leandro Ferreira         Residencia       Sim       Não        Sim
# 8    Santa Rita do Itueto         Residencia       Sim       Não        Sim
# 9            Nova Resende         Residencia       Sim       Sim        Sim
# 10          Montes Claros         Residencia       Não       Não        Não
# 11                Itabira         Residencia  Ignorado       Não        Sim
# 12                  Serro         Residencia       Não       Não        Sim
# 13  Santa Rita do Sapucaí         Residencia       Sim       Não        Sim
# 14              Simonésia  Comercio/Serviços       Sim       Não        Sim
# 15           Alto Caparaó         Residencia       Não       Sim        Sim
#
#    viol_psico viol_sexu    num_envolv      autor_sexo     orient_sex  \
# 0         Sim       Não            Um       Masculino  Heterossexual
# 1         Não       Não      Ignorado        Ignorado       Ignorado
# 2         Não       Não            Um       Masculino       Ignorado
# 3         Não       Sim      Ignorado       Masculino       Ignorado
# 4         Não       Não            Um       Masculino  Não se aplica
# 5         Não       Não            Um        Feminino       Ignorado
# 6         Sim       Sim            Um       Masculino  Heterossexual
# 7         Não       Não            Um       Masculino  Heterossexual
# 8         Sim       Não            Um       Masculino  Heterossexual
# 9         Não       Não            Um        Feminino  Heterossexual
# 10        Não       Sim            Um       Masculino       Ignorado
# 11        Não       Não            Um       Masculino       Ignorado
# 12        Não       Não            Um       Masculino  Heterossexual
# 13        Não       Não  Dois ou mais  Ambos os sexos       Ignorado
# 14        Sim       Não            Um       Masculino  Heterossexual
# 15        Não       Não            Um        Feminino  Heterossexual
#
#         ident_gen  duplicates_count
# 0   Não se aplica                 2
# 1        Ignorado                 2
# 2        Ignorado                 2
# 3        Ignorado                 2
# 4   Não se aplica                 2
# 5        Ignorado                 2
# 6   Não se aplica                 2
# 7   Não se aplica                 2
# 8   Não se aplica                 2
# 9   Não se aplica                 2
# 10       Ignorado                 2
# 11       Ignorado                 2
# 12  Não se aplica                 2
# 13       Ignorado                 2
# 14  Não se aplica                 2
# 15  Não se aplica                 2
# Duplicates count:  651
#
# duplicates_count
# 2    639
# 3     12
# Name: count, dtype: int64

# %%
df_concat = df_concat.drop_duplicates()

# %%
df_concat = df_concat.rename({"dt_notific": "dt_notificacao", 
                  "dt_nasc": "dt_nascimento_vitima", 
                  "nu_idade_n": "idade_vitima", 
                  "cs_raca": "raca_vitima", 
                  "id_mn_resi": "municipio_residencia", 
                  "local_ocor": "local_ocorrencia", 
                  "out_vezes": "outras_vezes", 
                  "les_autop": "lesao_autoprovocada", 
                  "viol_fisic": "viol_fisica", 
                  "viol_psico": "viol_psicologica", 
                  "viol_sexu": "viol_sexual", 
                  "num_envolv": "num_envolvidos",
                  "orient_sex": "orient_sex_vitima", 
                  "ident_gen": "ident_gen_vitima"}, axis=1)

def classify_violence(row):
    types = []

    if row["viol_fisica"] == "Sim":
        types.append("Física")
    if row["viol_psicologica"] == "Sim":
        types.append("Psicológica")
    if row["viol_sexual"] == "Sim":
        types.append("Sexual")

    return " | ".join(types) if types else "Não preenchido"
    
df_concat["tipo_violencia"] = df_concat.apply(classify_violence, axis=1)


##########################
### filling NaN values ###
##########################

### numeric columns ###

# converting datas
df_concat["dt_notificacao"] = pd.to_datetime(df_concat["dt_notificacao"], errors="coerce")
df_concat["dt_nascimento_vitima"] = pd.to_datetime(df_concat["dt_nascimento_vitima"], errors="coerce")

# split catches only the number
df_concat["idade_vitima"] = df_concat["idade_vitima"].astype(str).str.split(",", expand=True)[0]
df_concat["idade_vitima"] = pd.to_numeric(df_concat["idade_vitima"], errors="coerce")
df_concat["idade_vitima"] = df_concat["idade_vitima"].fillna(-1).astype("int16")

# returns the days quantity between this dates and catches the Integer part  (//)
df_concat["idade_calc"] = (df_concat["dt_notificacao"] - df_concat["dt_nascimento_vitima"]).dt.days // 365
# combines the age of the original column and the calc age. If still NaN, fill with -1
df_concat["idade_vitima"] = (
    df_concat["idade_calc"]
        .fillna(df_concat["idade_vitima"])
        .fillna(-1)
        .astype("int16")
)

### object columns ###

fillna_object_columns = ["raca_vitima", "municipio_residencia", "local_ocorrencia", "outras_vezes", "num_envolvidos", "lesao_autoprovocada", "autor_sexo", "orient_sex_vitima", "ident_gen_vitima"]

for col in fillna_object_columns:
    df_concat[col] = df_concat[col].fillna("Não preenchido")


#######################
### changing dtypes ###
#######################

df_concat = df_concat.astype({
    "dt_nascimento_vitima": "datetime64[ns]",
    "municipio_residencia": "string", 
    "idade_vitima": "int16", 
    "raca_vitima": "string", 
    "orient_sex_vitima": "string", 
    "ident_gen_vitima": "string", 
    "dt_notificacao": "datetime64[ns]", 
    "local_ocorrencia": "string", 
    "num_envolvidos": "string", 
    "tipo_violencia": "string",
    "lesao_autoprovocada": "string", 
    "outras_vezes": "string"
})


df_concat = df_concat[["dt_nascimento_vitima", "municipio_residencia", "idade_vitima", "raca_vitima", "orient_sex_vitima", "ident_gen_vitima", "dt_notificacao", "local_ocorrencia", "num_envolvidos", "tipo_violencia", "lesao_autoprovocada", "outras_vezes", "autor_sexo"]]

display(df_concat.head(20))
print("Shape: ", df_concat.shape)
# Out:
#    dt_nascimento_vitima  municipio_residencia  idade_vitima raca_vitima  \
# 0            1937-11-02  Governador Valadares            72       Parda
# 1            1992-04-30         Montes Claros            17       Parda
# 2            2003-04-07  Governador Valadares             7    Ignorado
# 3            1963-05-07   São José do Goiabal            46       Parda
# 4            1917-08-01         Jaboticatubas            92      Branca
# 5            2010-01-19          Pouso Alegre             0      Branca
# 6            1999-06-06                Bambuí            10      Branca
# 7            1955-01-30              Contagem            55    Ignorado
# 8            1980-09-08        Patos de Minas            29      Branca
# 9            1985-08-25       Várzea da Palma            24       Parda
# 10           1974-11-14       Várzea da Palma            35       Parda
# 11           1988-05-19         Montes Claros            21      Branca
# 12           1983-08-18         Montes Claros            26      Branca
# 13           1989-01-16         Montes Claros            20       Parda
# 14           1986-01-26         Montes Claros            23       Parda
# 15                  NaT         Montes Claros            21      Branca
# 16                  NaT         Montes Claros            17      Branca
# 17           1981-07-14        Belo Horizonte            28       Preta
# 18           2003-11-27        Belo Horizonte             6       Parda
# 19           2009-01-10        Belo Horizonte             1      Branca
#
#    orient_sex_vitima ident_gen_vitima dt_notificacao local_ocorrencia  \
# 0     Não preenchido   Não preenchido     2010-08-03       Residencia
# 1     Não preenchido   Não preenchido     2010-02-07       Residencia
# 2     Não preenchido   Não preenchido     2010-06-28         Ignorado
# 3     Não preenchido   Não preenchido     2010-01-07       Residencia
# 4     Não preenchido   Não preenchido     2010-05-20       Residencia
# 5     Não preenchido   Não preenchido     2010-07-09         Ignorado
# 6     Não preenchido   Não preenchido     2010-02-09       Residencia
# 7     Não preenchido   Não preenchido     2010-01-23       Residencia
# 8     Não preenchido   Não preenchido     2010-03-01         Ignorado
# 9     Não preenchido   Não preenchido     2010-02-07      Via pública
# 10    Não preenchido   Não preenchido     2010-02-01      Via pública
# 11    Não preenchido   Não preenchido     2010-01-02            Outro
# 12    Não preenchido   Não preenchido     2010-01-01       Residencia
# 13    Não preenchido   Não preenchido     2010-01-02      Via pública
# 14    Não preenchido   Não preenchido     2010-01-03       Residencia
# 15    Não preenchido   Não preenchido     2010-01-01       Residencia
# 16    Não preenchido   Não preenchido     2010-02-17      Via pública
# 17    Não preenchido   Não preenchido     2010-02-01       Residencia
# 18    Não preenchido   Não preenchido     2010-01-26       Residencia
# 19    Não preenchido   Não preenchido     2010-02-08       Residencia
#
#    num_envolvidos                 tipo_violencia lesao_autoprovocada  \
# 0              Um           Física | Psicológica                 Não
# 1              Um           Física | Psicológica                 Não
# 2              Um           Psicológica | Sexual                 Não
# 3              Um                 Não preenchido      Não preenchido
# 4    Dois ou mais                 Não preenchido      Não preenchido
# 5              Um                         Física                 Não
# 6              Um                         Física                 Não
# 7        Ignorado                         Física                 Não
# 8        Ignorado                         Física      Não preenchido
# 9              Um                         Física                 Não
# 10             Um                         Física                 Não
# 11             Um  Física | Psicológica | Sexual                 Não
# 12             Um                         Física                 Não
# 13             Um                         Física                 Não
# 14             Um                         Física                 Não
# 15             Um           Física | Psicológica                 Não
# 16   Dois ou mais                         Física            Ignorado
# 17             Um           Física | Psicológica                 Não
# 18             Um                         Sexual                 Não
# 19             Um                         Sexual            Ignorado
#
#    outras_vezes autor_sexo
# 0           Sim  Masculino
# 1      Ignorado  Masculino
# 2      Ignorado  Masculino
# 3      Ignorado   Feminino
# 4           Sim  Masculino
# 5      Ignorado   Feminino
# 6      Ignorado  Masculino
# 7      Ignorado   Ignorado
# 8           Não   Ignorado
# 9           Não   Feminino
# 10          Não  Masculino
# 11          Não  Masculino
# 12          Sim  Masculino
# 13          Sim  Masculino
# 14          Sim  Masculino
# 15     Ignorado  Masculino
# 16     Ignorado   Feminino
# 17          Sim  Masculino
# 18          Sim  Masculino
# 19          Não  Masculino
# Shape:  (471260, 13)

# %%
df_concat.isna().sum()
# Out:
# dt_nascimento_vitima    6042
# municipio_residencia       0
# idade_vitima               0
# raca_vitima                0
# orient_sex_vitima          0
# ident_gen_vitima           0
# dt_notificacao             0
# local_ocorrencia           0
# num_envolvidos             0
# tipo_violencia             0
# lesao_autoprovocada        0
# outras_vezes               0
# autor_sexo                 0
# dtype: int64

# %%
(df_concat["idade_vitima"] == -1).sum()
# Out:
# np.int64(38)

# %%
df_concat.index = df_concat.index + 1
df_concat.index.name = "id"
df_concat.to_csv("./dados_violencia_contra_mulher_SES/dados_violencia_mulheres_ses_concat_limpo.csv", index=True)

# %%
df = pd.read_csv(BASE_PATH / "dados_violencia_mulheres_ses_concat_limpo.csv")

display(df.head())
print("Shape", df.shape)
# Out:
#    id dt_nascimento_vitima  municipio_residencia  idade_vitima raca_vitima  \
# 0   1           1937-11-02  Governador Valadares            72       Parda
# 1   2           1992-04-30         Montes Claros            17       Parda
# 2   3           2003-04-07  Governador Valadares             7    Ignorado
# 3   4           1963-05-07   São José do Goiabal            46       Parda
# 4   5           1917-08-01         Jaboticatubas            92      Branca
#
#   orient_sex_vitima ident_gen_vitima dt_notificacao local_ocorrencia  \
# 0    Não preenchido   Não preenchido     2010-08-03       Residencia
# 1    Não preenchido   Não preenchido     2010-02-07       Residencia
# 2    Não preenchido   Não preenchido     2010-06-28         Ignorado
# 3    Não preenchido   Não preenchido     2010-01-07       Residencia
# 4    Não preenchido   Não preenchido     2010-05-20       Residencia
#
#   num_envolvidos        tipo_violencia lesao_autoprovocada outras_vezes  \
# 0             Um  Física | Psicológica                 Não          Sim
# 1             Um  Física | Psicológica                 Não     Ignorado
# 2             Um  Psicológica | Sexual                 Não     Ignorado
# 3             Um        Não preenchido      Não preenchido     Ignorado
# 4   Dois ou mais        Não preenchido      Não preenchido          Sim
#
#   autor_sexo
# 0  Masculino
# 1  Masculino
# 2  Masculino
# 3   Feminino
# 4  Masculino
# Shape (471260, 14)

# %%
df.columns
# Out:
# Index(['id', 'dt_nascimento_vitima', 'municipio_residencia', 'idade_vitima',
#        'raca_vitima', 'orient_sex_vitima', 'ident_gen_vitima',
#        'dt_notificacao', 'local_ocorrencia', 'num_envolvidos',
#        'tipo_violencia', 'lesao_autoprovocada', 'outras_vezes', 'autor_sexo'],
#       dtype='object')

# %% [markdown]
# # --------------------------------------------------------

# %%
test = pd.read_csv(BASE_PATH / "dados_violencia_mulheres_ses_concat.csv")
test
# Out:
#         dt_notific     dt_nasc nu_idade_n   cs_sexo   cs_raca  \
# 0       2010-08-03  1937-11-02         72  Feminino     Parda
# 1       2010-02-07  1992-04-30         17  Feminino     Parda
# 2       2010-06-28  2003-04-07          7  Feminino  Ignorado
# 3       2010-01-07  1963-05-07         46  Feminino     Parda
# 4       2010-05-20  1917-08-01         92  Feminino    Branca
# ...            ...         ...        ...       ...       ...
# 472041  2025-10-31  2002-01-15       23,0  Feminino     Parda
# 472042  2025-11-03  2009-02-11       16,0  Feminino  Indígena
# 472043  2025-10-23  1997-02-28       28,0  Feminino     Parda
# 472044  2025-10-23  1956-01-08       69,0  Feminino     Parda
# 472045  2025-10-20  2005-07-02       20,0  Feminino     Parda
#
#                   id_mn_resi  local_ocor out_vezes les_autop viol_fisic  \
# 0       Governador Valadares  Residencia       Sim       Não        Sim
# 1              Montes Claros  Residencia  Ignorado       Não        Sim
# 2       Governador Valadares    Ignorado  Ignorado       Não        Não
# 3        São José do Goiabal  Residencia  Ignorado       NaN        Não
# 4              Jaboticatubas  Residencia       Sim       NaN        Não
# ...                      ...         ...       ...       ...        ...
# 472041           São Gotardo  Residencia       Não       Sim        Não
# 472042        Patos de Minas  Residencia       Não       Sim        Sim
# 472043        Patos de Minas  Residencia       Sim       Sim        Sim
# 472044         Lagoa Formosa         NaN       NaN       NaN        NaN
# 472045        Patos de Minas  Residencia       Sim       Sim        Sim
#
#        viol_psico viol_sexu    num_envolv autor_sexo     orient_sex  \
# 0             Sim       Não            Um  Masculino            NaN
# 1             Sim       NaN            Um  Masculino            NaN
# 2             Sim       Sim            Um  Masculino            NaN
# 3             Não       Não            Um   Feminino            NaN
# 4             Não       Não  Dois ou mais  Masculino            NaN
# ...           ...       ...           ...        ...            ...
# 472041        Não       Não            Um   Feminino  Heterossexual
# 472042        Não       Não            Um   Feminino  Heterossexual
# 472043        Não       Não            Um   Feminino  Heterossexual
# 472044        NaN       NaN           NaN        NaN            NaN
# 472045        Não       Não            Um   Feminino       Ignorado
#
#             ident_gen
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 472041  Não se aplica
# 472042  Não se aplica
# 472043  Não se aplica
# 472044            NaN
# 472045       Ignorado
#
# [472046 rows x 16 columns]

# %%
test["dt_notific"].min()
# Out:
# '2010-01-01'

# %%
test["dt_notific"].max()
# Out:
# '2025-11-07'

# %%
test.isna().sum()
# Out:
# dt_notific        0
# dt_nasc        6068
# nu_idade_n       36
# cs_sexo           0
# cs_raca        5982
# id_mn_resi     1265
# local_ocor    11717
# out_vezes     15529
# les_autop     15789
# viol_fisic    12715
# viol_psico    17370
# viol_sexu     17863
# num_envolv    18096
# autor_sexo    13492
# orient_sex    79176
# ident_gen     79176
# dtype: int64
